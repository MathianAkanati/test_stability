# %%
import pandas as pd
import numpy as np
from google.cloud import storage
from google.cloud import bigquery
client = bigquery.Client()

# %%
query5 = """
SELECT * FROM `itg-btdppublished-gbl-ww-pd.btdp_ds_c2_9ff_rm_pcp_eu_pd.rmp_test`
"""
concentration = client.query(query5).to_dataframe()
# Out:
# /home/user/.local/lib/python3.10/site-packages/google/cloud/bigquery/table.py:1727: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(

# %%
concentration
# Out:
#                                  test_ms_id  test_ms_source_id  \
# 0      2633e7dc-846a-44fa-bcc5-8d4986ba26a9              48884
# 1      c918467c-371f-4932-a8c6-7dd869769cc4              32602
# 2      b969086c-37f7-441c-b41c-1846aba0209a               8382
# 3      a7096a88-6a9b-4e06-afef-05b5d7a78b4a              50742
# 4      14c1a901-8503-4a06-827c-b975f26d254d              33874
# ...                                     ...                ...
# 69165  cafcafef-aee3-43db-9b55-8e8594e3acdc              39106
# 69166  90835490-d38e-4f8d-b87f-7978af4d0305              26462
# 69167  4d234467-7e0e-4ff0-a1e9-eb80c364abf0              26475
# 69168  4a7c6955-9015-49c5-a1de-c6fa7ccd94b6              37836
# 69169  d0885bfc-6257-442c-b083-14b73f193bac              34348
#
#                                test_lims_id  test_lims_source_id  \
# 0                                      None                 <NA>
# 1                                      None                 <NA>
# ...
